# %% [markdown]
# # Бонусное ДЗ
#
# ### Студент: Яценко Кирилл

# %% [markdown]
# ## №1
#
# Дана шахматная доска 30 × 30 и позиции двух коней на ней. Определите, за какое минимальное число ходов можно поменять этих двух коней местами

# %%
from collections import deque

def is_valid(x, y, n):
    """Проверка, что координаты (x, y) находятся в пределах доски размером n x n."""
    return 0 <= x < n and 0 <= y < n

def min_knight_moves(n, start1, start2, end1, end2):
    """Находит минимальное количество ходов для обмена местами двух коней на доске размером n x n."""
    # Варианты ходов коня
    moves = [
        (2, 1), (2, -1), (-2, 1), (-2, -1),
        (1, 2), (1, -2), (-1, 2), (-1, -2)
    ]
    
    # Очередь для BFS
    queue = deque([(start1[0], start1[1], start2[0], start2[1], 0)])
    
    # Множество посещённых состояний
    visited = set()
    visited.add((start1[0], start1[1], start2[0], start2[1]))
    
    while queue:
        x1, y1, x2, y2, d = queue.popleft()
        
        # Если оба коня достигли своих конечных позиций
        if (x1, y1) == end1 and (x2, y2) == end2:
            return d
        
        for move1 in moves:
            new_x1, new_y1 = x1 + move1[0], y1 + move1[1]
            if is_valid(new_x1, new_y1, n):
                for move2 in moves:
                    new_x2, new_y2 = x2 + move2[0], y2 + move2[1]
                    if is_valid(new_x2, new_y2, n) and (new_x1, new_y1) != (new_x2, new_y2):
                        new_state = (new_x1, new_y1, new_x2, new_y2)
                        if new_state not in visited:
                            visited.add(new_state)
                            queue.append((new_x1, new_y1, new_x2, new_y2, d + 1))
    
    return -1  # В случае невозможности достичь цели

n = 30
start1 = (0, 0)
end1 = (29, 29)
start2 = (29, 29)
end2 = (0, 0)

# Минимальные шаги для обмена местами коней
min_steps = min_knight_moves(n, start1, start2, end1, end2)

print(f"Минимальное количество ходов для обмена местами коней: {min_steps}")
# Out:
# Минимальное количество ходов для обмена местами коней: 20

# %% [markdown]
# ## Объяснение алгоритма
# ### Функция is_valid:
# Проверяет, находятся ли координаты в пределах доски.
#
# ### Функция min_knight_moves:
#
# Использует очередь для реализации BFS, где каждая запись содержит позиции обоих коней и количество сделанных ходов.
#
# Начинает с начальных позиций коней и помещает их в очередь.
#
# Пока очередь не пуста, извлекает текущее состояние и проверяет, достигли ли оба коня своих целевых позиций. Если достигли, возвращает количество шагов.
#
# В противном случае добавляет все возможные ходы для обоих коней в очередь, избегая случаев, когда оба коня попадают на одну и ту же клетку одновременно.
#
# Множество visited используется для отслеживания уже посещённых состояний, чтобы избежать циклов и повторных посещений.
#
# Этот алгоритм гарантирует, что оба коня никогда не будут находиться на одной клетке одновременно и найдёт минимальное количество ходов для их обмена местами.

# %% [markdown]
# ## №2
# Дан взвешенный граф с положительными весами ребер.
# Найдите кратчайшие пути от вершины s до всех остальных, если на каждую вершину есть дополнительное ограничение: через вершину v можно проходить только в периоды длиной av, между которыми она «закрыта» на bv времени. Время работы — O(m log n) или O(n2).

# %%
# Out:
#   Cell In[2], line 1
#     Дан взвешенный граф с положительными весами ребер. Найдите кратчайшие пу-
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Алгоритм Прима используется для построения минимального остовного дерева в неориентированном графе, последовательно добавляя минимальные рёбра, которые соединяют уже построенное дерево с остальными вершинами. Однако для ориентированных графов (директед графов) этот подход не работает. Давайте рассмотрим, почему это так, на конкретном примере.
#
# Рассмотрим следующий ориентированный граф:
#
# - Вершины: \( A, B, C, D \)
# - Ребра (с весами):
#   - \( A \to B \) с весом 1
#   - \( A \to C \) с весом 4
#   - \( B \to C \) с весом 2
#   - \( B \to D \) с весом 5
#   - \( C \to D \) с весом 1
#   - \( D \to A \) с весом 3
#
# Теперь попробуем применить аналог алгоритма Прима для построения минимального ориентированного остовного дерева (arborescence), начиная с вершины \( A \).
#
# ### Шаги алгоритма Прима:
# 1. **Начальная вершина \( A \)**: Включаем \( A \) в дерево. Доступные рёбра из \( A \): \( A \to B \) (вес 1), \( A \to C \) (вес 4).
#    - Выбираем ребро \( A \to B \) (вес 1), так как оно минимальное.
#
# 2. **Теперь дерево включает вершины \( A \) и \( B \)**. Доступные рёбра: \( B \to C \) (вес 2), \( B \to D \) (вес 5), \( A \to C \) (вес 4).
#    - Выбираем ребро \( B \to C \) (вес 2), так как оно минимальное среди доступных.
#
# 3. **Теперь дерево включает вершины \( A, B \) и \( C \)**. Доступные рёбра: \( C \to D \) (вес 1), \( B \to D \) (вес 5), \( A \to C \) (вес 4).
#    - Выбираем ребро \( C \to D \) (вес 1), так как оно минимальное.
#
# 4. **Теперь дерево включает вершины \( A, B, C \) и \( D \)**. Все вершины охвачены.
#
# Мы получили ориентированное дерево с рёбрами \( A \to B \) (вес 1), \( B \to C \) (вес 2), и \( C \to D \) (вес 1).
#
# ### Проверка корректности:
# Теперь проверим, является ли это деревом минимального веса. Суммарный вес дерева: \( 1 + 2 + 1 = 4 \).
#
# Однако, рассмотрим другое возможное минимальное ориентированное дерево (arborescence):
# - Ребра \( A \to B \) (вес 1), \( B \to D \) (вес 5), \( D \to C \) (вес 1).
#
# Суммарный вес этого дерева: \( 1 + 5 + 1 = 7 \), что явно больше веса 4. Но для ориентации ребер, возможно, такие деревья не всегда минимальны, и пример демонстрирует несовместимость аналогичного подхода.
#
# Из-за направленности рёбер и необходимости обеспечения достижимости всех вершин из исходной вершины \( A \), выбор минимального ребра на каждом шагу не гарантирует оптимальное решение. Это показывает, что аналог алгоритма Прима не работает для построения минимального ориентированного остовного дерева.
